# %% [markdown]
# # Sawtooth Sweep
#
# We start by plotting a cosine function of frequency $f_{audio}$ in the range of 10's of Hz through 10's of kHz of amplitude x. This is function is the normalized voltage
#
# ![](../schematics/schematic1.svg)
#
# ![](../schematics/schematic2.svg)
#
# $$
# p(v,y,z,T) = z\eta(t)  + T_N + T\Phi\left(\frac{v+y}{T}\right) + T\Phi\left(\frac{v-y}{T}\right)
# $$
# $$
# \Phi(\phi) \equiv \phi\coth{\phi}
# $$
# $$
# y \equiv \frac{hf_{microwave}}{2k_B}
# $$
# $$
# v(t) = \frac{eV(t)}{2k_B} = x\cos{(2\pi f_{audio} t)}
# $$

# %%
import matplotlib.pyplot as plt
import numpy as np

f_audio = 440 # Hz
sample_rate = 101.1*f_audio #samples per second
sample_time = 0.05 # seconds
omega = 2*np.pi*f_audio
x = 0.5

# time values

t_values = np.linspace(0, sample_time,int(sample_rate*sample_time))
v_values = x*np.cos(omega*t_values)
f = plt.figure()
f.set_figwidth(10)
f.set_figheight(8)

#v_values = t_values + t_values
                       
plt.plot(t_values, v_values)
    
plt.xlabel('t[s]')
plt.ylabel('v[kevlin]')
plt.title('Plot of v vs t')
#plt.ylim(0, 1.5)
plt.show()

# %% [markdown]
# to make a sawtooth we use the modulo function with the number of points in a ramp, normalizing the sawtooth amplitude to 1

# %%
import matplotlib.pyplot as plt
import numpy as np

f_audio = 440 # Hz
sample_rate = 100*f_audio #samples per second
sample_time = 0.05 # seconds
t_ramp = 0.01 # seconds

omega = 2*np.pi*f_audio

x = 0.5
n_ramp = int(t_ramp*sample_rate) # number of sample points per ramp

# time values

t_values = np.linspace(0, sample_time,int(sample_rate*sample_time))
v_values = ((t_values*sample_rate)%n_ramp)/(sample_rate*t_ramp)

f = plt.figure()
f.set_figwidth(10)
f.set_figheight(8)

#v_values = t_values + t_values
                       
plt.plot(t_values, v_values)
    
plt.xlabel('t[s]')
plt.ylabel('v[kevlin]')
plt.title('Plot of v vs t')
#plt.ylim(0, 1.5)
plt.show()

# %% [markdown]
# now multiply the two functions together to get the full signal we put into the audio bias line of the junction:

# %%
import matplotlib.pyplot as plt
import numpy as np

f_audio = 240 # Hz
sample_rate = 100*f_audio #samples per second
sample_time = 0.35 # seconds
t_ramp = 0.1 # seconds

omega = 2*np.pi*f_audio

x = 0.5
n_ramp = int(t_ramp*sample_rate) # number of sample points per ramp

# time values

t_values = np.linspace(0, sample_time,int(sample_rate*sample_time))
v_values = x*np.cos(omega*t_values)*((t_values*sample_rate)%n_ramp)/(sample_rate*t_ramp)
f = plt.figure()
f.set_figwidth(20)
f.set_figheight(8)

#v_values = t_values + t_values
                       
plt.plot(t_values, v_values)
    
plt.xlabel('t[s]')
plt.ylabel('v[kevlin]')
plt.title('audio voltage on junction in kelvin units')
#plt.ylim(0, 1.5)
plt.show()

# %%
import numpy as np
from IPython.display import Audio

# Set the sample rate and duration
sr = 44100  # 44.1 kHz sample rate
duration = 5  # 5 seconds

# Create the time array
t = np.linspace(0, duration, sr * duration, endpoint=False)

# Create the 60 Hz sine wave
omega = 2 * np.pi * 440
sine_waveform = np.sin(omega * t)

# Play the sine wave
audio = Audio(data=sine_waveform, rate=sr)
display(audio)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy import signal
from scipy.io import wavfile
from IPython.display import Audio


f_audio = 440 # Hz
sample_rate = 100*f_audio #samples per second
sample_time = 5 # seconds
t_ramp = 0.5 # seconds

omega = 2*np.pi*f_audio

x = 0.1
n_ramp = int(t_ramp*sample_rate) # number of sample points per ramp

# time values

t_values = np.linspace(0, sample_time,int(sample_rate*sample_time))
v_values = x*np.cos(omega*t_values)*((t_values*sample_rate)%n_ramp)/(sample_rate*t_ramp)
f = plt.figure()
f.set_figwidth(20)
f.set_figheight(8)

#v_values = t_values + t_values
                       
plt.plot(t_values, v_values)

int_values = np.round(255*v_values/x)

audio = Audio(data=int_values, rate=sample_rate)
display(audio)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
def Phi(x):    
    return (x) / np.tanh(x + 0.000001)
    
def p(v,y,z,T):
    return z*np.random.normal(1) + T*Phi((v + y)/T) + T*Phi((v - y)/T)

# %%
import matplotlib.pyplot as plt
import numpy as np

f_audio = 840 # Hz
sample_rate = 100*f_audio #samples per second
sample_time = 0.35 # seconds
t_ramp = 0.1 # seconds

omega = 2*np.pi*f_audio

x = 0.5
y = 0.25
z = 0
T = 0.025
T_N = 0.5

n_ramp = int(t_ramp*sample_rate) # number of sample points per ramp

# time values


f = plt.figure()
f.set_figwidth(20)
f.set_figheight(4)

plt.plot(t_values, v_values)
    
plt.xlabel('t[s]')
plt.ylabel('v(t)[kevlin]')
plt.title('audio bias voltage on junction in kelvin')
#plt.ylim(0, 1.5)
plt.show()

t_values = np.linspace(0, sample_time,int(sample_rate*sample_time))
v_values = x*np.cos(omega*t_values)*((t_values*sample_rate)%n_ramp)/(sample_rate*t_ramp)
p_values = T_N + p(v_values,y,z,T)

f = plt.figure()
f.set_figwidth(20)
f.set_figheight(4)

#v_values = t_values + t_values
                       
plt.plot(t_values, p_values)
    
plt.xlabel('t[s]')
plt.ylabel('p[kevlin]')
plt.title('integrated noise power around microwave frequency in kelvin')
#plt.ylim(0, 1.5)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

f_audio = 440 # Hz
sample_rate = 100*f_audio #samples per second
sample_time = 2 # seconds
t_ramp = 0.3 # seconds

omega = 2*np.pi*f_audio

x = 0.5
y = 0.25
z = 0
T = 0.025
T_N = 0.5
n_ramp = int(t_ramp*sample_rate) # number of sample points per ramp
z = 0.1

 
t_values = np.linspace(0, sample_time,int(sample_rate*sample_time))
v_values = x*np.cos(omega*t_values)*((t_values*sample_rate)%n_ramp)/(sample_rate*t_ramp)
fluctuations = z*np.random.normal(loc=0, scale=1, size=len(t_values))
p_values = T_N + p(v_values,y,z,T) + fluctuations

f = plt.figure()
f.set_figwidth(20)
f.set_figheight(4)

plt.plot(t_values, v_values)
    
plt.xlabel('t[s]')
plt.ylabel('v(t)[kevlin]')
plt.title('audio bias voltage on junction in kelvin')
#plt.ylim(0, 1.5)
plt.show()


f = plt.figure()
f.set_figwidth(20)
f.set_figheight(4)

#v_values = t_values + t_values
                       
plt.plot(t_values, p_values)
    
plt.xlabel('t[s]')
plt.ylabel('p[kevlin]')
plt.title('integrated noise power around microwave frequency in kelvin')
#plt.ylim(0, 1.5)
plt.show()
audio = Audio(data=p_values, rate=sample_rate)
display(audio)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
audio = Audio(data=v_values, rate=sample_rate)
display(audio)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
